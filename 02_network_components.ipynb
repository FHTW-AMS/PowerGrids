# %%
from src import battery, load_profiles

# %%
#automatically reload changes in imports
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Example of a local battery
local_battery = battery.Battery(
    #  charge value reduced, as we are looking at 15 minute intervals
    charge_kWh=50,
    discharge_kWh=50,
)

# %%
# State of charge of the battery
local_battery.SoC
# Out:
# 0.0

# %%
# Show available methods and attributes of the battery
dir(local_battery)
# Out:
# ['SoC',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'capacity_kWh',
#  'charge',
#  'charge_kWh',
#  'current_kWh',
#  'discharge',
#  'discharge_kWh',
#  'max_charge',
#  'max_discharge']

# %%
# Small example of load management with battery
